# %% [markdown]
# <a href="https://colab.research.google.com/github/saghanarajmohan/Spotify-Music-Trends-Analysis/blob/main/Spotify_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
import pandas as pd

df = pd.read_csv('spotify_dataset.csv')
df.head()

# %%
df.shape
df.info()
df.describe()

# %%
df = df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])

# %%
df.isnull().sum()

# %%
df = df.dropna()
df = df.drop_duplicates()

# %%
genres = df['artist_genres'].str.split(';').explode()

top_genres = genres.value_counts().head(10)

plt.figure(figsize=(8,5))
top_genres.plot(kind='bar')
plt.title("Top 10 Genres on Spotify")
plt.xlabel("Genre")
plt.ylabel("Number of Songs")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['popularity'], bins=30)
plt.title("Distribution of Song Popularity")
plt.xlabel("Popularity")
plt.ylabel("Count")
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(df[features])

df_scaled = pd.DataFrame(scaled_features, columns=features)

df_scaled.mean().plot(kind='bar', figsize=(8,5))
plt.title("Normalized Average Audio Features")
plt.ylabel("Normalized Value")
plt.show()

# %%
yearly_popularity = df.groupby('year')['popularity'].mean()

plt.figure(figsize=(8,5))
yearly_popularity.plot()
plt.title("Average Song Popularity Over Years")
plt.xlabel("Year")
plt.ylabel("Popularity")
plt.show()

# %%
top_artists = df['principal_artist_name'].value_counts().head(10)

plt.figure(figsize=(8,5))
top_artists.plot(kind='barh')
plt.title("Top 10 Artists by Number of Songs")
plt.xlabel("Number of Songs")
plt.ylabel("Artist")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[features + ['loudness']].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Between Audio Features")
plt.show()

# %%
plt.figure(figsize=(8,5))
top_genres.plot(kind='bar')
plt.title("Top 10 Genres on Spotify")
plt.savefig("top_genres.png")
plt.show()
